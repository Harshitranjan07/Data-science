# %% [markdown]
# <a href="https://colab.research.google.com/github/Harshitranjan07/python-lec/blob/main/Lec02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
s = input()

left = 0
right = len(s) - 1
is_palindrome = True

while left < right:
    if s[left] != s[right]:
        is_palindrome = False
        break

    left += 1
    right -= 1

if is_palindrome:
    print("Palindrome")
else:
    print("Not Palindrome")

# %%
list = [1,2,3,'hello','c',[2,4]]

print(list)

#append()
list.append([2,3,4])
print(list)

#extend()
list.extend([2,3,4])
print(list)

#insert(index,value)
list.insert(2,"value")
print(list)

#pop()
list.pop()
print(list)

#remove()
list.remove(2)
print(list)

#index()
print(list.index(2))

#count()
print(list.count(3))

#sort()
list.sort()

#sum , min , max , sorted
# list = [2,6,1,9,4]
# list2 = [6,2,9,0,1]

# list.sum()
# print(list)

# list.sorted()
# print(list)

# %%
list = [10,6,3,9,7]
a=sorted(list)
print(list)
print(a)
# Out:
# [10, 6, 3, 9, 7]
# [3, 6, 7, 9, 10]

# %%
tp = (1,2,37,4)

a = tuple(sorted(tp))
print(a)

#Tuples function

# category        functions
# count values    count()
# find            index()
# size            len()
# total           sum()
# highest/lowest  max()/min()
# sort            sorted()(returns list)
# Out:
# (1, 2, 4, 37)

# %%
lst1=[]
lst2 =[]
size =int(input())

for i in range (size):
  x=int(input())

  lst1.append(x)

for j in range(size):
  y = int(input())

  lst2.append(y)

lst3 = []

for i in range(size):
  lst3.append(lst1[i] + lst2[i] )

print(lst3)
# Out:
# 5
# 1
# 2
# 3
# 7
# 44
# 1
# 5
# 9
# 11
# 6
# [2, 7, 12, 18, 50]
