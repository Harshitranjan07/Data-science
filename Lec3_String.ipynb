# %% [markdown]
# <a href="https://colab.research.google.com/github/Harshitranjan07/Data-science/blob/main/Lec3_String.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def add(a,b):
  #body of function
  return a+b

# %%
#lambda function

x = lambda a,b: b * a
print(x(2,3))
# Out:
# 6

# %%
st = ""
print(len(st))

st = "harshit ranjan"
up = st.upper()
print (up)

lo = st.lower()
print(lo)

tit = st.title()
print(tit)

cap = st.capitalize()
print(cap)
# Out:
# 0
# HARSHIT RANJAN
# harshit ranjan
# Harshit Ranjan
# Harshit ranjan

# %%
st = '    Harshit Kumar Singh'

#strip
str = st.strip('')
print(str)
# Out:
#     Harshit Kumar Singh

# %%
first_name = 'Harshit'
last_name = '    Kumar Singh'

first_name = first_name.strip()
last_name = last_name.strip()

print(first_name + ' ' + last_name )
# Out:
# Harshit Kumar Singh

# %%
a = "today"
b = "   weather"
c = "is GooD    "

cap = a.capitalize()
# low = c.lower()
rep = c.replace("GooD", "Bad").lower()

print(cap.strip() + " " + b.strip() + " " + rep.strip())
# Out:
# Today weather is bad

# %%
st = "Harshit is batman"
f = st.find("batman")

print(f)

start = st.startswith("Harshit")
print(start)

end = st.endswith("batman")
print(end)
# Out:
# 11
# True
# True

# %%
#Explore sets
st = {2,2,23,2,1}
print(st)
# Out:
# {1, 2, 23}

# %%
dict = {
    "name": "Harshit",
    "age" : 20,
    "occupation" : "student"
}
